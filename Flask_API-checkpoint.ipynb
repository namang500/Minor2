# %%
import os
import urllib
import base64
from flask import Flask,request
from flask import Flask,render_template, redirect,url_for
import glob


app=Flask(__name__)

name_of_file="image"
ctr=0

path_to_images= r'C:\Users\india\minor2\recieved_images'


known_faces=[]
known_face_encodings=[]

@app.route('/<bitmapString>')

def bitmapStr(bitmapString):
    bitmapString=bitmapString.replace(" ","")
    firstStr=bitmapString.replace('@','/')
    secondStr=firstStr.replace('&','+')
    missing_padding=len(bitmapString)%4

    file1=open(complete_name,"wb")
    file1.write(image_64_decode)
    file1.close()

    return 'Strnmn,m'

@app.route('/greet',methods=['GET','POST'])


def greet():
    a=request.form['greet']
    return a

@app.route('/',methods=['GET','POST'])

def index():
    imageFile = request.form["image"]
    counter = request.form["count"]
    personName = request.form["personName"]
    image_64_decode=base64.b64decode(imageFile)
    
    filepath = os.path.join(path_to_images,"a"+"_"+"_"+ name_of_file+".PNG")
    
    if not os.path.exists(path_to_images):
            os.makedirs(path_to_images)   
    file1 = open(filepath, "wb")
    

    file1.write(image_64_decode)


    file1.close()
    known_faces=glob.glob("Flask_images\\*.PNG")
    

#     print("known faces")
#     face=predict_script.detect_faces(known_faces)
#     if face is None:
#             label = "Face cannot be Extracted"
#     else:
#             label=""
                #print(label)        
        
    
    
    return ""

@app.route('/bacon',methods=['GET','POST'])
def bacon():
    if request.method=='POST':
        return 'Method used is POST'
    else:
        return 'Method used is GET'

if(__name__=="__main__"):
    app.run(debug=True,host=' 100.112.65.194',port=5001)

@app.route('/<user>')
def index(user=None):
    return render_template("user.html",user=user)

UPLOAD_FOLDER = '/home/sukrit/Desktop/FlaskBoston/UploadFiles'
ALLOWED_EXTENSIONS = set(['txt', 'pdf', 'png', 'jpg', 'jpeg', 'gif'])

app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-8-fb2e2f929b6d> in <module>()
#      81
#      82 if(__name__=="__main__"):
# ---> 83     app.run(debug=True,host=' 100.112.65.194',port=5001)
#      84
#      85 @app.route('/<user>')
#
# c:\users\india\anaconda3\envs\tensorflow\lib\site-packages\flask\app.py in run(self, host, port, debug, **options)
#     839         options.setdefault('use_debugger', self.debug)
#     840         try:
# --> 841             run_simple(host, port, self, **options)
#     842         finally:
#     843             # reset the first request information if the development server
#
# c:\users\india\anaconda3\envs\tensorflow\lib\site-packages\werkzeug\serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#     793             s = socket.socket(address_family, socket.SOCK_STREAM)
#     794             s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 795             s.bind(get_sockaddr(hostname, port, address_family))
#     796             if hasattr(s, 'set_inheritable'):
#     797                 s.set_inheritable(True)
#
# gaierror: [Errno 11001] getaddrinfo failed
